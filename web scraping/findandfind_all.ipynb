# %%
from bs4 import BeautifulSoup
import requests

# %%
path="https://www.scrapethissite.com/pages/forms/"

# %%
page=requests.get(path)

# %%
soup=BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Hockey Teams: Forms, Searching and Pagination | Scrape This Site | A public sandbox for learning web scraping</title>
# <link href="/static/images/scraper-icon.png" rel="icon" type="image/png"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components." name="description"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/css/bootstrap.min.css" integrity="sha256-MfvZlkHCEqatNoGiOXveE8FIwMzZg4W85qfrfIFBfYc= sha512-dTfge/zgoMYpP7QbHy4gWMEGsbsdZeCXz7irItjcC3sPUFtf0kuFbDz/ixG7ArTxmDjLXDmezHubeNikyKGVyQ==" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:400,700" rel="stylesheet" type="text/css"/>
# <link href="/static/css/styles.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
soup.find_all('p')
# Out:
# [<p class="lead">
#                              Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                              Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.
#                          </p>,
#  <p>
#  <i class="glyphicon glyphicon-education"></i> There are <a href="/lessons/">8 video lessons</a> that show you how to scrape this page.
#                          </p>,
#  <p>
#
#                                  Data via
#                                  <a class="data-attribution" href="http://www.opensourcesports.com/hockey/" target="_blank">http://www.opensourcesports.com/hockey/</a>
#  </p>]

# %%
a=soup.find('p', class_="lead").text.strip()

# %%
print(a)
# Out:
# Browse through a database of NHL team stats since 1990. Practice building a scraper that handles common website interface components.
#                             Take a look at how pagination and search elements change the URL as your browse. Build a web scraper that can conduct searches and paginate through the results.

# %%
soup.find_all('th')
# Out:
# [<th>
#                              Team Name
#                          </th>,
#  <th>
#                              Year
#                          </th>,
#  <th>
#                              Wins
#                          </th>,
#  <th>
#                              Losses
#                          </th>,
#  <th>
#                              OT Losses
#                          </th>,
#  <th>
#                              Win %
#                          </th>,
#  <th>
#                              Goals For (GF)
#                          </th>,
#  <th>
#                              Goals Against (GA)
#                          </th>,
#  <th>
#                              + / -
#                          </th>]

# %%
table=soup.find_all('th')
print(table)
# Out:
# [<th>
#                             Team Name
#                         </th>, <th>
#                             Year
#                         </th>, <th>
#                             Wins
#                         </th>, <th>
#                             Losses
#                         </th>, <th>
#                             OT Losses
#                         </th>, <th>
#                             Win %
#                         </th>, <th>
#                             Goals For (GF)
#                         </th>, <th>
#                             Goals Against (GA)
#                         </th>, <th>
#                             + / -
#                         </th>]

# %%
table_head=[head.text.strip() for head in table]

# %%
print(table_head)
# Out:
# ['Team Name', 'Year', 'Wins', 'Losses', 'OT Losses', 'Win %', 'Goals For (GF)', 'Goals Against (GA)', '+ / -']

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=table_head)
df
# Out:
# Empty DataFrame
# Columns: [Team Name, Year, Wins, Losses, OT Losses, Win %, Goals For (GF), Goals Against (GA), + / -]
# Index: []

# %%
table_row=soup.findAll("tr")
print(table_row)
# Out:
# [<tr>
# <th>
#                             Team Name
#                         </th>
# <th>
#                             Year
#                         </th>
# <th>
#                             Wins
#                         </th>
# <th>
#                             Losses
#                         </th>
# <th>
#                             OT Losses
#                         </th>
# <th>
#                             Win %
#                         </th>
# <th>
#                             Goals For (GF)
#                         </th>
# <th>
#                             Goals Against (GA)
#                         </th>
# <th>
#                             + / -
#                         </th>
# </tr>, <tr class="team">
# <td class="name">
#                             Boston Bruins
#                         </td>
# <td class="year">
#                             1990
#                         </td>
# <td class="wins">
#                             44
# ...

# %%
for row in table_row[1:]:
    row_data = row.find_all('td')
    # print(row_data)
    world_row_data= [data.text.strip() for data in row_data]
    # print(world_row_data)
    length= len(df)
    df.loc[length] = world_row_data
# Out:
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75

# %%
df
# Out:
#              Team Name  Year Wins Losses OT Losses  Win % Goals For (GF)  \
# 0        Boston Bruins  1990   44     24             0.55            299
# 1       Buffalo Sabres  1990   31     30            0.388            292
# 2       Calgary Flames  1990   46     26            0.575            344
# 3   Chicago Blackhawks  1990   49     23            0.613            284
# 4    Detroit Red Wings  1990   34     38            0.425            273
# ..                 ...   ...  ...    ...       ...    ...            ...
# 70       Winnipeg Jets  1990   26     43            0.325            260
# 71       Boston Bruins  1991   36     32             0.45            270
# 72      Buffalo Sabres  1991   31     37            0.388            289
# 73      Calgary Flames  1991   31     37            0.388            296
# 74  Chicago Blackhawks  1991   36     29             0.45            257
#
#    Goals Against (GA) + / -
# 0                 264    35
# 1                 278    14
# ...

# %%
df.to_csv(r'C:\Users\Dell\Documents\Python-for-data-analysis\web scraping\teamsheet.csv',index=False)

# %%
data=['sujan','sapkota','helllo']
aa=pd.DataFrame(columns=data)

# %%
aa
# Out:
# Empty DataFrame
# Columns: [sujan, sapkota, helllo]
# Index: []

# %%
data1=['sujan','sapkota','sujan']

# %%
row=[d for d in data1]
print(row)
length=len(aa)
aa.loc[length]=row
# Out:
# ['sujan', 'sapkota', 'sujan']

# %%
aa
# Out:
#    sujan  sapkota helllo
# 0  sujan  sapkota  sujan
# 1  sujan  sapkota  sujan
